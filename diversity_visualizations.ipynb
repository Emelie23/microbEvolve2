# %% [markdown]
# # Visualizations Diversity

# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = "data"

# %% [markdown]
# ### Alpha-Rarefaction

# %%
Visualization.load("/home/jovyan/microbEvolve2/data/processed/alpha_rarefaction.qzv")
# Out:
# <visualization: Visualization uuid: 1c21aada-e8c5-43c2-8a23-fb3fbb2fa709>

# %% [markdown]
# ### Alpha significance

# %%
#shannon
#months 2 and 4 are significant, p=0.017
Visualization.load("/home/jovyan/microbEvolve2/data/processed/hannon-group-significance.qzv")

# %%
#pielou
#months 4 and 6 are significant, p=0.01
Visualization.load("/home/jovyan/microbEvolve2/data/processed/pielou-group-significance.qzv")

# %% [markdown]
# ### Spearman correlation

# %%
#shannon
Visualization.load("/home/jovyan/microbEvolve2/data/processed/shannon_correlation.qzv")

# %%
#pielou
Visualization.load("/home/jovyan/microbEvolve2/data/processed/hannon-group-significance.qzv")

# %% [markdown]
# ### PERMANOVA test

# %%
#months 2 and 4 are significant
Visualization.load("/home/jovyan/microbEvolve2/data/raw/boots_kmer_diversity/distance_matrices/braycurtis_significance.qzv")

# %% [markdown]
# ### PERMANOVA test with filtered metadata

# %%
Visualization.load("/home/jovyan/microbEvolve2/data/raw/boots_kmer_diversity/distance_matrices/braycurtis_significance_filtered.qzv")
