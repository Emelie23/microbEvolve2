# %% [markdown]
# ## 02 Diversity

# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
scripts_dir = "src"
data_dir = "../data"

# %% [markdown]
# ## Metadata modification

# %% [markdown]
# ### merge metadata
# First step would be to merge metadata_per sample and metadata_per age

# %%
# !python "{scripts_dir}/merge_metadata.py"
# Out:
# Merging metadata...
# Metadata file written to ../data/raw/metadata.tsv
# Metadata file with type information written to ../data/raw/metadata_withtypes.tsv

# %% [markdown]
# ### filter metadata to only have infants with samples at 2,4 and 6 months

# %%
# !python "{scripts_dir}/filter_metadata.py"
# Out:
# Filtering metadata for ...
# Filtered metadata file written to ../data/raw/metadata_filtered.tsv

# %% [markdown]
# ### collapse metadata

# %%
# !python "{scripts_dir}/infant_time_metadata.py"
# !python "{scripts_dir}/collapse_metadata.py"
# Out:
# Create new metadata file with infant id + timepoint...
# Metadata file created successfuly...
# Start script to collapse metadata (and intermediate metadata file that is needed to collapse feature table)...
# Collapsed metadata file created successfully...

# %% [markdown]
# ## Diversity

# %% [markdown]
# ### Rarefaction

# %% [markdown]
# Rarefaction was performed to assess sampling depth.
# Then explain k-kmer size selection (say that code for this can be found in archive) - show plot.

# %%
! sh {scripts_dir}/diversity_alpha.sh
# Out:
# sh: src/diversity_alpha.sh: No such file or directory

# %%
Visualization.load(f"{data_dir}/processed/alpha_rarefaction.qzv")
