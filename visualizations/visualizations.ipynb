# %% [markdown]
# # Visualizations Quality Control and Denoising

# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = "data"

# %% [markdown]
# ### Quality Control Visualization

# %%
Visualization.load(f"{data_dir}/processed/demux_paired_end.qzv")
# Out:
# <visualization: Visualization uuid: 1c21aada-e8c5-43c2-8a23-fb3fbb2fa709>

# %% [markdown]
# ### Denoising Vizualization

# %% [markdown]
# #### No truncation of reads but non-default (50 bps) overlap when joining

# %%
#Summary of read count per sample before and after denoising 
Visualization.load(f"{data_dir}/processed/dada2_stats_0.qzv")
# Out:
# <visualization: Visualization uuid: a5f5af4f-b23a-4a61-ac1e-649d7a62d75d>

# %%
#Lists all the representative sequences (ASVs) we have after denoising 
Visualization.load(f"{data_dir}/processed/dada2_rep_set_0.qzv")
# Out:
# <visualization: Visualization uuid: ed30202b-18c2-43d1-9238-221aaaa81242>

# %%
#Interactive summary of the feature table
Visualization.load(f"{data_dir}/processed/dada2_table_0.qzv")
# Out:
# <visualization: Visualization uuid: e888cdeb-051c-4625-9695-2643a615f9d5>

# %% [markdown]
# #### Truncation of reads and default (12 bps) overlap when joining
#
# - Truncation of forward reads: 300
# - Truncation of reverse reads: 218

# %%
#Summary of read count per sample before and after denoising 
Visualization.load(f"{data_dir}/processed/dada2_stats_1.qzv")
# Out:
# <visualization: Visualization uuid: ccf1537c-b820-4bc2-b7e6-004d94ce0eb7>

# %%
#Lists all the representative sequences (ASVs) we have after denoising 
Visualization.load(f"{data_dir}/processed/dada2_rep_set_1.qzv")
# Out:
# <visualization: Visualization uuid: 306aaefb-5bc6-4e81-a6de-9517d02ac36f>

# %%
#Interactive summary of the feature table
Visualization.load(f"{data_dir}/processed/dada2_table_0.qzv")
# Out:
# <visualization: Visualization uuid: e888cdeb-051c-4625-9695-2643a615f9d5>
