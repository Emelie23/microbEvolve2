# %% [markdown]
# # Visualizations Quality Control and Denoising

# %%
import os
import pandas as pd
from qiime2 import Visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_dir = "data"

# %% [markdown]
# ### Quality Control Visualization

# %%
Visualization.load(f"{data_dir}/processed/demux_paired_end.qzv")
# Out:
# <visualization: Visualization uuid: 8c166b15-6ed0-4ab2-89e4-446711fea4c2>

# %% [markdown]
# ### Denoising Vizualization

# %%
#Summary of read count per sample before and after denoising 
Visualization.load(f"{data_dir}/processed/dada2_stats.qzv")

# %%
#Lists all the representative sequences (ASVs) we have after denoising 
Visualization.load(f"{data_dir}/processed/dada2_rep_set.qzv")

# %%
#Interactive summary of the feature table
Visualization.load(f"{data_dir}/processed/dada2_table.qzv")
