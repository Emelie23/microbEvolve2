# %% [markdown]
# We need to add plotly to environment.yaml file in case tutor wants to run the code

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sb

# %matplotlib inline

# %%
input_dir = "data/raw"

# %%
umap_braycurtis = pd.read_csv(
                 f"{input_dir}/umap_pcoa_export/umap_braycurtis/ordination.txt",
                 sep='\t',
                 index_col=0,
                 skiprows= 9,
                 header=None
                 )
umap_braycurtis
# Out:
#                           1         2         3
# 0
# sample_1           5.557002  4.662980  4.191576
# sample_10          8.691114  3.532264  6.784888
# sample_100        10.656794 -0.218025  9.044934
# sample_101        10.476485 -0.560879  9.064379
# sample_102         6.178450  6.513831  5.123354
# ...                     ...       ...       ...
# sample_97          9.841166  0.587900  7.477924
# sample_98          9.747794  0.938276  7.633801
# sample_99         10.584906 -0.180270  9.199159
# Biplot             0.000000  0.000000       NaN
# Site constraints   0.000000  0.000000       NaN
#
# [122 rows x 3 columns]

# %%
metadata = pd.read_csv(
                    f"{input_dir}/metadata.tsv",
                    sep='\t',
                    index_col=0,
                    header=0
                    )

# %%
umap_braycurtis_metadata_merged = pd.merge(umap_braycurtis, metadata, how='left', left_index=True, right_index=True)
umap_braycurtis_metadata_merged["infant_id"] = umap_braycurtis_metadata_merged["infant_id"].astype("category")

# %%
fig = px.scatter_3d(umap_braycurtis_metadata_merged,
                    x=1,
                    y=2,
                    z=3,
                    color='infant_id',
                    #size='petal_length',
                    #size_max=18,
                    symbol='timepoint',
                    #symbol='species',
                    opacity=0.7)

fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()
